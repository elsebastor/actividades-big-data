# %% [markdown]
# # **Maestría en Inteligencia Artificial Aplicada**
#
# ## Curso: **Análisis de grandes volúmenes de datos**
#
# ### Tecnológico de Monterrey
#
# ### Dr. Nestor Velasco Bermeo
#
# ## Avance de proyecto 4: Sistema de Recomendación
#
# ### **Sistema de recomendacion de prendas basado en SVD**

# %% [markdown]
# #### **Nombres y matrículas de los integrantes del equipo:**
#
# * Salvador Martínez Morales - A01273366
# * Jhamyr Arnulfo Alcalde Oballe - A01795401
# * Sebastian Toro Salgado – A01793644

# %%
# librerías

import numpy as np
import pandas as pd
import gdown
import warnings

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')
warnings.filterwarnings('ignore')

# %%
'''
    Cargamos nuestro data set con los rankins
    
    Como podemos ver contiene las columnas: 
        fit: fit feedback
        user_id: a unique id for the customer
        bust: bust measurement of customer
        item_id: unique product id
        weight: weight of the product
        rating: dating of the product 0-10
        rented for: reason of rent
        review_text: customer comments
        body type: clothe body type
        review_summary: short customer comments
        category: the category of the product
        height: height of the customer
        size: the standardized size of the product
        age: customer age
        review_date: date of review
'''

df = pd.read_json('renttherunway_final_data.json', lines=True)
df.head(5)
# Out:
#    fit  user_id bust size  item_id  weight  rating     rented for  \
# 0  fit   420272       34d  2260466  137lbs    10.0       vacation
# 1  fit   273551       34b   153475  132lbs    10.0          other
# 2  fit   360448       NaN  1063761     NaN    10.0          party
# 3  fit   909926       34c   126335  135lbs     8.0  formal affair
# 4  fit   151944       34b   616682  145lbs    10.0        wedding
#
#                                          review_text          body type  \
# 0  An adorable romper! Belt and zipper were a lit...          hourglass
# 1  I rented this dress for a photo shoot. The the...  straight & narrow
# 2  This hugged in all the right places! It was a ...                NaN
# 3  I rented this for my company's black tie award...               pear
# 4  I have always been petite in my upper body and...           athletic
#
#                                       review_summary category height  size  \
# 0                               So many compliments!   romper  5' 8"    14
# 1                            I felt so glamourous!!!     gown  5' 6"    12
# 2  It was a great time to celebrate the (almost) ...   sheath  5' 4"     4
# 3   Dress arrived on time and in perfect condition.     dress  5' 5"     8
# 4                    Was in love with this dress !!!     gown  5' 9"    12
#
#      age         review_date
# 0   28.0      April 20, 2016
# 1   36.0       June 18, 2013
# 2  116.0   December 14, 2015
# 3   34.0   February 12, 2014
# 4   27.0  September 26, 2016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158648 entries, 0 to 158647
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   fit             158648 non-null  object
#  1   user_id         158648 non-null  int64
#  2   bust size       143493 non-null  object
#  3   item_id         158648 non-null  int64
#  4   weight          133945 non-null  object
#  5   rating          158582 non-null  float64
#  6   rented for      158639 non-null  object
#  7   review_text     158648 non-null  object
#  8   body type       146658 non-null  object
#  9   review_summary  158648 non-null  object
#  10  category        158648 non-null  object
#  11  height          158090 non-null  object
#  12  size            158648 non-null  int64
#  13  age             157861 non-null  float64
#  14  review_date     158648 non-null  object
# dtypes: float64(2), int64(3), object(10)
# memory usage: 18.2+ MB

# %%
# Contar valores nulos por columna
null_counts = df.isnull().sum()

# Mostrar el resultado
print(null_counts)
# Out:
# fit                   0
# user_id               0
# bust size         15155
# item_id               0
# weight            24703
# rating               66
# rented for            9
# review_text           0
# body type         11990
# review_summary        0
# category              0
# height              558
# size                  0
# age                 787
# review_date           0
# dtype: int64

# %%
'''
    Extraemos las columnas 'user_id' 'item_id' 'rating' que serán utilizadas para nuestro análisis
'''
columnas = ['user_id','item_id','rating'] 
my_dt = df[columnas]

my_dt.head(5)
# Out:
#    user_id  item_id  rating
# 0   420272  2260466    10.0
# 1   273551   153475    10.0
# 2   360448  1063761    10.0
# 3   909926   126335     8.0
# 4   151944   616682    10.0

# %%
'''
    Una vez que tenemos el data set unificado, podemos calcular el promedio de calificaciones por cada prenda
'''

my_dt.groupby('item_id')['rating'].mean().head()
# Out:
# item_id
# 123373    8.793651
# 123793    9.554277
# 124204    9.306061
# 124553    8.591687
# 125424    8.949602
# Name: rating, dtype: float64

# %%
'''
    El ordenamiento anterior tiene un problema, en caso de que una prenda solo se haya calificado una sola vez con calificación de 10
    aparecerá en los primeros lugares, sin embargo, eso no significa que sea del agrado para la mayoría de usuarios
    por lo que, haremos un conteo de los ranking por prenda
'''

my_dt.groupby('item_id')['rating'].count().sort_values(ascending=False).head()
# Out:
# item_id
# 126335    1801
# 174086    1428
# 123793    1391
# 132738    1289
# 145906    1250
# Name: rating, dtype: int64

# %%
my_dt["item_id"].nunique()
# Out:
# 5773

# %% [markdown]
# Para contrarestar el afecto anteriormente descrito, se generará un nuevo data set agregando las columnas rating y numero de ratings (calificaciones)

# %%
ratings_mean_count = pd.DataFrame(my_dt.groupby('item_id')['rating'].mean())
ratings_mean_count['rating_counts'] = pd.DataFrame(my_dt.groupby('item_id')['rating'].count())
ratings_mean_count.head()
# Out:
#            rating  rating_counts
# item_id
# 123373   8.793651            567
# 123793   9.554277           1391
# 124204   9.306061            660
# 124553   8.591687            409
# 125424   8.949602            377

# %%
'''
    Ahora graficaremos el numero de calificaciones representada por la columna rating_counts de nuestro data set.
    De los resultados podemos observar que tenemos que la mayoría de prendas han recibido menos de 100 calificaciones
    Hay prendas que no tienen más de 100 recomendaciones
'''

plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating_counts'].hist(bins=50)
# Out:
# <Axes: >

# %%
'''
    Como podemos observar en el siguietne histograma, la mayoría de calificaciones se concentran entre 8 y 10
'''

plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['rating'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# # Similutudes entre prendas

# %%
ratings_mean_count.groupby('item_id')['rating_counts'].mean()
# Out:
# item_id
# 123373      567.0
# 123793     1391.0
# 124204      660.0
# 124553      409.0
# 125424      377.0
#             ...
# 2963850      11.0
# 2964470       2.0
# 2965009       3.0
# 2965924       3.0
# 2966087       6.0
# Name: rating_counts, Length: 5773, dtype: float64

# %%
ratings_mean_count.shape
# Out:
# (5773, 2)

# %%
'''
   Extraemos las prendas con menos de 10 comentarios
'''
rare_clothes = ratings_mean_count[ratings_mean_count.groupby('item_id')['rating_counts'].mean() <= 10].index
rare_clothes.shape
# Out:
# (2684,)

# %%
'''
    De nuestro data set original se eliminan aquellas prendas con pocos comentarios
'''
common_clothes = my_dt[~my_dt["item_id"].isin(rare_clothes)]
common_clothes.shape
# Out:
# (146175, 3)

# %%
'''
    Se genera una matriz con los titulos y sus correspondientes ratings
'''
user_clothe_rating = common_clothes.pivot_table(index='user_id', columns='item_id', values='rating')
user_clothe_rating.head()
# Out:
# item_id  123373   123793   124204   124553   125424   125465   125564   \
# user_id
# 9            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 25           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 44           NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47           NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# item_id  126335   127081   127495   ...  2945782  2948324  2952142  2954118  \
# user_id                             ...
# 9            NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 25           NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 35           NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 44           NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
# 47           NaN      NaN      NaN  ...      NaN      NaN      NaN      NaN
#
# item_id  2955585  2955734  2958376  2960969  2962646  2963850
# user_id
# 9            NaN      NaN      NaN      NaN      NaN      NaN
# 25           NaN      NaN      NaN      NaN      NaN      NaN
# 35           NaN      NaN      NaN      NaN      NaN      NaN
# 44           NaN      NaN      NaN      NaN      NaN      NaN
# 47           NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 3089 columns]

# %% [markdown]
# # Función para recomendaciones

# %%
def clothes_recommend(clothe, head):
    
    if clothe in user_clothe_rating.columns:
        clothes_rating = user_clothe_rating[clothe] # Prenda base para correlación
        corr_clothes = user_clothe_rating.corrwith(clothes_rating) # Función de correlación
        result_df = pd.DataFrame(corr_clothes, columns=['Correlation'])
        result_df.dropna(inplace=True)
        result_df = result_df.join(ratings_mean_count['rating_counts'])
        result_df = result_df.sort_values('Correlation', ascending=False).head(head)
        print('Si rentaste la prenda {}, te pueden interesar las siguientes prendas:'.format(clothe))
        print(result_df[1:10])
    else:
        print(f"La columna '{clothe}' no existe en el DataFrame.")

# %%
clothes_recommend(127495,11)
# Out:
# Si rentaste la prenda 127495, te pueden interesar las siguientes prendas:
#          Correlation  rating_counts
# item_id
# 153475           1.0            444
# 1447941          1.0             65
# 293358           1.0             30
# 2863546          1.0             24
# 532135           1.0            231
# 1598962          1.0             54
# 1050242          1.0             82
# 127495           1.0            381
# 833599           1.0             47

# %% [markdown]
# ## Análisis de desempeño

# %% [markdown]
# ### Medición del Tiempo de Ejecución

# %%
import timeit

def measure_time():
    setup_code = '''
import numpy as np
import pandas as pd

# Carga DF
df = pd.read_json('renttherunway_final_data.json', lines=True)
columnas = ['user_id','item_id','rating'] 
my_dt = df[columnas]

ratings_mean_count = pd.DataFrame(my_dt.groupby('item_id')['rating'].mean())
ratings_mean_count['rating_counts'] = pd.DataFrame(my_dt.groupby('item_id')['rating'].count())

rare_clothes = ratings_mean_count[ratings_mean_count.groupby('item_id')['rating_counts'].mean() <= 10].index

common_clothes = my_dt[~my_dt["item_id"].isin(rare_clothes)]

user_clothe_rating = common_clothes.pivot_table(index='user_id', columns='item_id', values='rating')

def clothes_recommend(clothe, head):

    if clothe in user_clothe_rating.columns:
        clothes_rating = user_clothe_rating[clothe] # Prenda base para correlación
        corr_clothes = user_clothe_rating.corrwith(clothes_rating) # Función de correlación
        result_df = pd.DataFrame(corr_clothes, columns=['Correlation'])
        result_df.dropna(inplace=True)
        result_df = result_df.join(ratings_mean_count['rating_counts'])
        result_df = result_df.sort_values('Correlation', ascending=False).head(head)
        return result_df[1:10]
    else:
        return None
        '''

    test_code = '''
    clothes_recommend(127495,11)
'''

    times = timeit.repeat(setup=setup_code, stmt=test_code, repeat=3, number=5)
    print(f'Tiempo de ejecución: {min(times)} segundos')

measure_time()
# Out:
# Tiempo de ejecución: 2.940967200000159 segundos

# %% [markdown]
# ### Perfilado del Código con cProfile

# %%
import cProfile

def clothes_recommend(clothe, head):

    if clothe in user_clothe_rating.columns:
        clothes_rating = user_clothe_rating[clothe] # Prenda base para correlación
        corr_clothes = user_clothe_rating.corrwith(clothes_rating) # Función de correlación
        result_df = pd.DataFrame(corr_clothes, columns=['Correlation'])
        result_df.dropna(inplace=True)
        result_df = result_df.join(ratings_mean_count['rating_counts'])
        result_df = result_df.sort_values('Correlation', ascending=False).head(head)
        return result_df[1:10]
    else:
        return None
    
cProfile.run('clothes_recommend(127495,11)')
# Out:
#          581197 function calls (565643 primitive calls) in 2.760 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    2.760    2.760 3761528363.py:3(clothes_recommend)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         1    0.000    0.000    2.760    2.760 <string>:1(<module>)
#     15464    0.006    0.000    0.006    0.000 __init__.py:34(using_copy_on_write)
#         4    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#         3    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#         1    0.000    0.000    0.000    0.000 _asarray.py:108(<setcomp>)
#         1    0.000    0.000    0.000    0.000 _asarray.py:27(require)
#         2    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         2    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#         2    0.000    0.000    0.000    0.000 _dtype.py:346(_name_get)
#       368    0.007    0.000    0.017    0.000 _methods.py:101(_mean)
#         5    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#      3093    0.003    0.000    0.028    0.000 _methods.py:61(_all)
#       368    0.002    0.000    0.003    0.000 _methods.py:67(_count_reduce_items)
#       368    0.003    0.000    0.003    0.000 _methods.py:90(_clip)
#       736    0.001    0.000    0.002    0.000 _ufunc_config.py:452(_no_nep50_warning)
#         1    0.000    0.000    0.000    0.000 _validators.py:128(_check_for_invalid_keys)
#         1    0.000    0.000    0.000    0.000 _validators.py:141(validate_kwargs)
#         5    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 _validators.py:354(validate_ascending)
#         1    0.000    0.000    0.000    0.000 _validators.py:49(_check_for_default_values)
#        44    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 algorithms.py:1131(take)
#         1    0.000    0.000    0.000    0.000 api.py:102(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api.py:106(_get_distinct_objs)
#         1    0.000    0.000    0.000    0.000 api.py:120(_get_combined_index)
#         1    0.000    0.000    0.000    0.000 api.py:202(union_indexes)
#         1    0.000    0.000    0.000    0.000 api.py:72(get_objs_combined_axis)
#         1    0.000    0.000    2.756    2.756 apply.py:1061(apply_standard)
#         1    0.021    0.021    2.754    2.754 apply.py:1070(apply_series_generator)
#         1    0.000    0.000    0.001    0.001 apply.py:1102(wrap_results)
#         1    0.000    0.000    0.000    0.000 apply.py:1137(series_generator)
#      3090    0.008    0.000    0.165    0.000 apply.py:1139(<genexpr>)
#         1    0.000    0.000    0.000    0.000 apply.py:1190(result_index)
#         1    0.000    0.000    0.000    0.000 apply.py:121(__init__)
#         1    0.000    0.000    0.000    0.000 apply.py:1643(reconstruct_func)
#         1    0.000    0.000    0.000    0.000 apply.py:773(__init__)
#         1    0.000    0.000    0.000    0.000 apply.py:82(frame_apply)
#         3    0.000    0.000    0.000    0.000 apply.py:856(columns)
#         1    0.000    0.000    2.756    2.756 apply.py:864(apply)
#         1    0.000    0.000    0.000    0.000 astype.py:157(astype_array)
#         1    0.000    0.000    0.000    0.000 astype.py:191(astype_array_safe)
#         1    0.000    0.000    0.000    0.000 astype.py:249(astype_is_view)
#         4    0.000    0.000    0.000    0.000 base.py:1010(view)
#         3    0.000    0.000    0.000    0.000 base.py:1146(take)
#         3    0.000    0.000    0.000    0.000 base.py:1176(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 base.py:122(_reset_cache)
#         1    0.000    0.000    0.000    0.000 base.py:1250(copy)
#        20    0.000    0.000    0.000    0.000 base.py:1671(name)
#         1    0.000    0.000    0.000    0.000 base.py:1697(_validate_names)
#         1    0.000    0.000    0.000    0.000 base.py:176(isna)
#         3    0.000    0.000    0.000    0.000 base.py:1765(_get_names)
#         2    0.000    0.000    0.000    0.000 base.py:1979(nlevels)
#         4    0.000    0.000    0.000    0.000 base.py:2229(is_monotonic_increasing)
#         3    0.000    0.000    0.000    0.000 base.py:2313(is_unique)
#        22    0.000    0.000    0.000    0.000 base.py:238(construct_from_string)
#         1    0.000    0.000    0.000    0.000 base.py:269(join)
#         3    0.000    0.000    0.000    0.000 base.py:2744(inferred_type)
#         2    0.000    0.000    0.000    0.000 base.py:2776(_is_multi)
#         2    0.000    0.000    0.000    0.000 base.py:2794(_na_value)
#         1    0.000    0.000    0.000    0.000 base.py:3071(drop_duplicates)
#         1    0.000    0.000    0.000    0.000 base.py:3211(_validate_sort_keyword)
#         2    0.000    0.000    0.000    0.000 base.py:332(array)
#         1    0.000    0.000    0.000    0.000 base.py:3439(_wrap_setop_result)
#         1    0.000    0.000    0.000    0.000 base.py:3449(intersection)
#         1    0.000    0.000    0.000    0.000 base.py:3535(_intersection)
#         1    0.000    0.000    0.000    0.000 base.py:3565(_wrap_intersection_result)
#      3097    0.001    0.000    0.001    0.000 base.py:363(ndim)
#         1    0.000    0.000    0.000    0.000 base.py:3760(_assert_can_do_setop)
#         1    0.000    0.000    0.000    0.000 base.py:3766(_convert_can_do_setop)
#         1    0.000    0.000    0.000    0.000 base.py:3777(get_loc)
#         1    0.000    0.000    0.000    0.000 base.py:381(_left_indexer_unique)
#         1    0.000    0.000    0.000    0.000 base.py:400(_inner_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:4191(_validate_positional_slice)
#         3    0.000    0.000    0.000    0.000 base.py:4201(_convert_slice_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:4557(join)
#         7    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#         5    0.000    0.000    0.001    0.000 base.py:475(__new__)
#         1    0.000    0.000    0.000    0.000 base.py:4983(_join_monotonic)
#         3    0.000    0.000    0.000    0.000 base.py:5058(_can_use_libjoin)
#         2    0.000    0.000    0.000    0.000 base.py:5088(values)
#        61    0.000    0.000    0.000    0.000 base.py:5144(_values)
#        11    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#         4    0.000    0.000    0.000    0.000 base.py:5204(_get_join_target)
#         1    0.000    0.000    0.000    0.000 base.py:5224(_from_join_target)
#         5    0.000    0.000    0.000    0.000 base.py:5323(__contains__)
#      6181    0.013    0.000    0.016    0.000 base.py:5373(__getitem__)
#         6    0.000    0.000    0.000    0.000 base.py:540(<genexpr>)
#      6178    0.023    0.000    0.081    0.000 base.py:541(to_numpy)
#         4    0.000    0.000    0.000    0.000 base.py:5425(_getitem_slice)
#         2    0.000    0.000    0.000    0.000 base.py:5437(_can_hold_identifiers_and_holds_name)
#         1    0.000    0.000    0.000    0.000 base.py:5455(append)
#         1    0.000    0.000    0.000    0.000 base.py:5486(<setcomp>)
#         3    0.000    0.000    0.000    0.000 base.py:549(find)
#         1    0.000    0.000    0.000    0.000 base.py:5491(_concat)
#         1    0.000    0.000    0.000    0.000 base.py:5495(<listcomp>)
#      3095    0.002    0.000    0.003    0.000 base.py:5552(equals)
#         5    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#         5    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 base.py:6324(_maybe_downcast_for_indexing)
#         1    0.000    0.000    0.000    0.000 base.py:6394(_should_compare)
#         1    0.000    0.000    0.000    0.000 base.py:6415(_is_comparable_dtype)
#        18    0.000    0.000    0.000    0.000 base.py:649(_simple_new)
#         1    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:6685(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:674(_with_infer)
#         2    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#      3092    0.003    0.000    0.009    0.000 base.py:74(__len__)
#        17    0.000    0.000    0.001    0.000 base.py:7593(ensure_index)
#         1    0.000    0.000    0.000    0.000 base.py:7683(_validate_join_method)
#         8    0.000    0.000    0.000    0.000 base.py:7688(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 base.py:7723(_unpack_nested_dtype)
#         6    0.000    0.000    0.000    0.000 base.py:773(_view)
#         1    0.000    0.000    0.000    0.000 base.py:782(_rename)
#      3095    0.001    0.000    0.001    0.000 base.py:791(is_)
#         7    0.000    0.000    0.000    0.000 base.py:82(shape)
#        18    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#        21    0.000    0.000    0.000    0.000 base.py:84(<genexpr>)
#         7    0.000    0.000    0.000    0.000 base.py:842(_engine)
#         8    0.000    0.000    0.000    0.000 base.py:86(_validate_set_axis)
#      3172    0.002    0.000    0.003    0.000 base.py:909(__len__)
#         8    0.000    0.000    0.000    0.000 base.py:974(dtype)
#         4    0.000    0.000    0.000    0.000 blocks.py:1249(shape)
#      3091    0.004    0.000    0.004    0.000 blocks.py:1253(iget)
#         2    0.000    0.000    0.000    0.000 blocks.py:1262(_slice)
#         4    0.000    0.000    0.000    0.000 blocks.py:1287(take_nd)
#         4    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#         4    0.000    0.000    0.000    0.000 blocks.py:253(fill_value)
#         7    0.000    0.000    0.000    0.000 blocks.py:2645(maybe_coerce_values)
#         2    0.000    0.000    0.000    0.000 blocks.py:266(mgr_locs)
#        10    0.000    0.000    0.000    0.000 blocks.py:2674(get_block_type)
#         2    0.000    0.000    0.000    0.000 blocks.py:2703(new_block_2d)
#         7    0.000    0.000    0.000    0.000 blocks.py:2716(new_block)
#         4    0.000    0.000    0.000    0.000 blocks.py:274(make_block)
#         5    0.000    0.000    0.000    0.000 blocks.py:2795(extend_blocks)
#         4    0.000    0.000    0.000    0.000 blocks.py:292(make_block_same_class)
#         2    0.000    0.000    0.000    0.000 blocks.py:324(slice_block_columns)
#         2    0.000    0.000    0.000    0.000 blocks.py:387(apply)
#         1    0.000    0.000    0.000    0.000 blocks.py:398(reduce)
#         2    0.000    0.000    0.000    0.000 blocks.py:414(_split_op_result)
#      3097    0.001    0.000    0.001    0.000 blocks.py:718(dtype)
#         1    0.000    0.000    0.000    0.000 blocks.py:723(astype)
#         2    0.000    0.000    0.000    0.000 blocks.py:790(copy)
#         4    0.000    0.000    0.000    0.000 cast.py:1157(maybe_infer_to_datetimelike)
#         5    0.001    0.000    0.001    0.000 cast.py:124(maybe_convert_platform)
#         1    0.000    0.000    0.000    0.000 cast.py:1433(find_common_type)
#         5    0.000    0.000    0.000    0.000 cast.py:1580(construct_1d_object_array_from_listlike)
#         4    0.000    0.000    0.000    0.000 cast.py:551(maybe_promote)
#         2    0.000    0.000    0.000    0.000 common.py:103(_maybe_match_name)
#         7    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         3    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:1122(<lambda>)
#         2    0.000    0.000    0.000    0.000 common.py:1198(is_bool_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:121(classes)
#        10    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#         3    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#         7    0.000    0.000    0.000    0.000 common.py:1270(is_1d_only_ea_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:1277(is_extension_array_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#        10    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:1375(_is_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:1399(_get_dtype)
#        13    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#      6181    0.003    0.000    0.003    0.000 common.py:152(cast_scalar_indexer)
#         4    0.000    0.000    0.000    0.000 common.py:1571(validate_all_hashable)
#         8    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#         4    0.000    0.000    0.000    0.000 common.py:1596(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:174(not_none)
#         3    0.000    0.000    0.000    0.000 common.py:178(<genexpr>)
#         3    0.000    0.000    0.000    0.000 common.py:195(any_not_none)
#         3    0.000    0.000    0.000    0.000 common.py:199(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#         3    0.000    0.000    0.000    0.000 common.py:295(maybe_make_list)
#         2    0.000    0.000    0.000    0.000 common.py:301(maybe_iterable_to_list)
#         9    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#      6182    0.006    0.000    0.006    0.000 common.py:529(is_string_or_object_np_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:536(is_string_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:568(require_length_match)
#         2    0.000    0.000    0.000    0.000 common.py:572(condition)
#         2    0.000    0.000    0.000    0.000 common.py:81(get_op_result_name)
#         2    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#         1    0.000    0.000    0.000    0.000 concat.py:157(concat)
#         1    0.000    0.000    0.000    0.000 concat.py:202(_maybe_reindex_columns_na_proxy)
#         1    0.000    0.000    0.000    0.000 concat.py:405(__init__)
#         1    0.000    0.000    0.000    0.000 concat.py:480(_get_ndims)
#         1    0.000    0.000    0.000    0.000 concat.py:494(_clean_keys_and_objs)
#         1    0.000    0.000    0.000    0.000 concat.py:52(concat_compat)
#         1    0.000    0.000    0.000    0.000 concat.py:545(_get_sample_object)
#         1    0.000    0.000    0.000    0.000 concat.py:567(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:622(get_result)
#         1    0.000    0.000    0.000    0.000 concat.py:693(_get_result_dim)
#         1    0.000    0.000    0.000    0.000 concat.py:699(new_axes)
#         1    0.000    0.000    0.000    0.000 concat.py:702(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:707(_get_comb_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:717(_get_concat_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:73(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:751(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:770(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 concat.py:777(_concat_indexes)
#         1    0.000    0.000    0.000    0.000 concat.py:94(concatenate_managers)
#         8    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         6    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         2    0.000    0.000    0.000    0.000 config.py:153(_set_option)
#         1    0.000    0.000    0.000    0.000 config.py:471(__init__)
#         1    0.000    0.000    0.000    0.000 config.py:479(__enter__)
#         1    0.000    0.000    0.000    0.000 config.py:480(<listcomp>)
#         1    0.000    0.000    0.000    0.000 config.py:485(__exit__)
#         8    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#         8    0.000    0.000    0.000    0.000 config.py:635(_get_root)
#         9    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#         2    0.000    0.000    0.000    0.000 config.py:665(_get_registered_option)
#         8    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#         1    0.000    0.000    0.000    0.000 config.py:688(_warn_if_deprecated)
#         2    0.000    0.000    0.000    0.000 config.py:886(inner)
#         3    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         2    0.000    0.000    0.000    0.000 construction.py:237(ndarray_to_mgr)
#         2    0.000    0.000    0.000    0.000 construction.py:405(_check_values_indices_shape_match)
#         8    0.000    0.000    0.000    0.000 construction.py:416(extract_array)
#         1    0.000    0.000    0.000    0.000 construction.py:423(dict_to_mgr)
#         1    0.000    0.000    0.000    0.000 construction.py:481(<listcomp>)
#        14    0.000    0.000    0.000    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.000    0.000 construction.py:487(<listcomp>)
#         7    0.000    0.000    0.001    0.000 construction.py:517(sanitize_array)
#         2    0.000    0.000    0.000    0.000 construction.py:585(_ensure_2d)
#         1    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#         1    0.000    0.000    0.000    0.000 construction.py:638(_extract_index)
#         5    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#         7    0.000    0.000    0.000    0.000 construction.py:696(_sanitize_ndim)
#         7    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#         2    0.000    0.000    0.000    0.000 construction.py:742(_get_axes)
#         7    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 construction.py:769(_try_cast)
#         1    0.000    0.000    0.000    0.000 construction.py:96(arrays_to_mgr)
#       368    0.000    0.000    0.002    0.000 contextlib.py:114(__enter__)
#       368    0.001    0.000    0.002    0.000 contextlib.py:123(__exit__)
#       368    0.001    0.000    0.002    0.000 contextlib.py:261(helper)
#       368    0.001    0.000    0.001    0.000 contextlib.py:86(__init__)
#         2    0.000    0.000    0.000    0.000 dtypes.py:1054(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:1305(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:1835(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:2228(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:342(construct_from_string)
#         2    0.000    0.000    0.000    0.000 dtypes.py:831(construct_from_string)
#      3109    0.003    0.000    0.003    0.000 flags.py:51(__init__)
#      9283    0.002    0.000    0.002    0.000 flags.py:55(allows_duplicate_labels)
#      9282    0.008    0.000    0.008    0.000 flags.py:87(allows_duplicate_labels)
#         1    0.000    0.000    2.756    2.756 frame.py:10170(apply)
#         6    0.000    0.000    0.000    0.000 frame.py:1030(axes)
#         5    0.000    0.000    0.000    0.000 frame.py:1047(shape)
#         1    0.000    0.000    0.001    0.001 frame.py:10580(join)
#         1    0.000    0.000    0.000    0.000 frame.py:1096(_can_fast_transpose)
#         1    0.000    0.000    0.000    0.000 frame.py:1111(_values)
#         1    0.000    0.000    2.756    2.756 frame.py:11219(corrwith)
#      3089    0.005    0.000    2.561    0.001 frame.py:11295(<lambda>)
#         1    0.000    0.000    0.001    0.001 frame.py:11435(_reduce)
#         1    0.000    0.000    0.000    0.000 frame.py:11458(blk_func)
#         1    0.000    0.000    0.000    0.000 frame.py:11522(<listcomp>)
#         1    0.000    0.000    0.001    0.001 frame.py:11620(all)
#         1    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#         1    0.000    0.000    0.000    0.000 frame.py:3767(transpose)
#         1    0.000    0.000    0.000    0.000 frame.py:3951(T)
#      3091    0.015    0.000    0.157    0.000 frame.py:3983(_ixs)
#         6    0.000    0.000    0.001    0.000 frame.py:4062(__getitem__)
#      3090    0.011    0.000    0.080    0.000 frame.py:4608(_box_col_values)
#         5    0.000    0.000    0.000    0.000 frame.py:4623(_clear_item_cache)
#         3    0.000    0.000    0.001    0.000 frame.py:4626(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 frame.py:6488(isna)
#         1    0.000    0.000    0.001    0.001 frame.py:6538(dropna)
#         1    0.000    0.000    0.000    0.000 frame.py:655(_constructor)
#        11    0.000    0.000    0.000    0.000 frame.py:659(_constructor_from_mgr)
#      3091    0.006    0.000    0.039    0.000 frame.py:678(_constructor_sliced_from_mgr)
#         3    0.000    0.000    0.000    0.000 frame.py:694(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:6997(sort_values)
#       368    0.000    0.000    0.000    0.000 fromnumeric.py:1561(_diagonal_dispatcher)
#       368    0.001    0.000    0.002    0.000 fromnumeric.py:1565(diagonal)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1877(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:1881(nonzero)
#       368    0.000    0.000    0.000    0.000 fromnumeric.py:2096(_clip_dispatcher)
#       368    0.001    0.000    0.005    0.000 fromnumeric.py:2100(clip)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2416(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2421(all)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2974(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2979(prod)
#       369    0.001    0.000    0.004    0.000 fromnumeric.py:53(_wrapfunc)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:71(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:72(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 frozen.py:76(__getitem__)
#         4    0.000    0.000    0.000    0.000 function.py:64(__call__)
#       368    0.000    0.000    0.000    0.000 function_base.py:2525(_cov_dispatcher)
#       368    0.020    0.000    0.054    0.000 function_base.py:2530(cov)
#       368    0.000    0.000    0.000    0.000 function_base.py:2752(_corrcoef_dispatcher)
#       368    0.008    0.000    0.072    0.000 function_base.py:2757(corrcoef)
#       368    0.000    0.000    0.000    0.000 function_base.py:348(iterable)
#       368    0.000    0.000    0.000    0.000 function_base.py:393(_average_dispatcher)
#       368    0.004    0.000    0.030    0.000 function_base.py:398(average)
#      3089    0.024    0.000    0.116    0.000 generic.py:10185(align)
#      3089    0.015    0.000    0.039    0.000 generic.py:10535(_align_series)
#         1    0.000    0.000    0.001    0.001 generic.py:12169(_logical_func)
#         1    0.000    0.000    0.000    0.000 generic.py:1565(__invert__)
#         1    0.000    0.000    0.000    0.000 generic.py:1771(_is_label_reference)
#         2    0.000    0.000    0.000    0.000 generic.py:1793(<genexpr>)
#         2    0.000    0.000    0.000    0.000 generic.py:1798(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:1826(_check_label_or_level_ambiguity)
#         1    0.000    0.000    0.000    0.000 generic.py:1847(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:1870(_get_label_or_level_values)
#         1    0.000    0.000    0.000    0.000 generic.py:1903(<listcomp>)
#      3109    0.013    0.000    0.016    0.000 generic.py:278(__init__)
#      3103    0.004    0.000    0.021    0.000 generic.py:339(_from_mgr)
#      9282    0.003    0.000    0.003    0.000 generic.py:363(attrs)
#     18626    0.009    0.000    0.013    0.000 generic.py:37(_check)
#         1    0.000    0.000    0.000    0.000 generic.py:3995(_maybe_update_cacher)
#         1    0.000    0.000    0.000    0.000 generic.py:4027(take)
#     18565    0.003    0.000    0.003    0.000 generic.py:405(flags)
#         1    0.000    0.000    0.000    0.000 generic.py:4142(_take_with_is_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:4159(xs)
#     18626    0.011    0.000    0.025    0.000 generic.py:42(_instancecheck)
#         3    0.000    0.000    0.000    0.000 generic.py:4342(_getitem_slice)
#         4    0.000    0.000    0.000    0.000 generic.py:4361(_slice)
#         6    0.000    0.000    0.000    0.000 generic.py:4379(_set_is_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:4402(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:4883(_update_inplace)
#         2    0.000    0.000    0.000    0.000 generic.py:511(_validate_dtype)
#        28    0.000    0.000    0.000    0.000 generic.py:572(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 generic.py:5818(head)
#         9    0.000    0.000    0.000    0.000 generic.py:586(_get_axis)
#         8    0.000    0.000    0.000    0.000 generic.py:592(_get_block_manager_axis)
#      9284    0.042    0.000    0.062    0.000 generic.py:6236(__finalize__)
#         2    0.000    0.000    0.000    0.000 generic.py:6270(<genexpr>)
#         3    0.000    0.000    0.000    0.000 generic.py:6277(<genexpr>)
#         6    0.000    0.000    0.000    0.000 generic.py:6284(__getattr__)
#      9289    0.020    0.000    0.020    0.000 generic.py:6301(__setattr__)
#         1    0.000    0.000    0.000    0.000 generic.py:6432(dtypes)
#         1    0.000    0.000    0.000    0.000 generic.py:6463(astype)
#         5    0.000    0.000    0.000    0.000 generic.py:667(_info_axis)
#         7    0.000    0.000    0.000    0.000 generic.py:696(ndim)
#         1    0.000    0.000    0.000    0.000 generic.py:720(size)
#         8    0.000    0.000    0.000    0.000 generic.py:807(_set_axis)
#         3    0.000    0.000    0.000    0.000 indexing.py:1165(_check_deprecated_callable_usage)
#         3    0.000    0.000    0.000    0.000 indexing.py:1176(__getitem__)
#         1    0.000    0.000    0.000    0.000 indexing.py:1205(_getbool_axis)
#         1    0.000    0.000    0.000    0.000 indexing.py:1397(_getitem_axis)
#         2    0.000    0.000    0.000    0.000 indexing.py:161(iloc)
#         1    0.000    0.000    0.000    0.000 indexing.py:1667(_validate_integer)
#         2    0.000    0.000    0.000    0.000 indexing.py:1719(_getitem_axis)
#         1    0.000    0.000    0.000    0.000 indexing.py:1756(_get_slice_axis)
#         1    0.000    0.000    0.000    0.000 indexing.py:2632(check_bool_indexer)
#         1    0.000    0.000    0.000    0.000 indexing.py:2752(need_slice)
#         9    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#         1    0.000    0.000    0.000    0.000 indexing.py:305(loc)
#         1    0.000    0.000    0.000    0.000 indexing.py:732(__call__)
#         5    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#         1    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         3    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#        22    0.000    0.000    0.000    0.000 inference.py:334(is_hashable)
#         2    0.000    0.000    0.000    0.000 inference.py:373(is_sequence)
#         1    0.000    0.000    0.000    0.000 inspect.py:73(isclass)
#      3090    0.028    0.000    0.038    0.000 managers.py:1012(iget)
#         1    0.000    0.000    0.000    0.000 managers.py:1483(reduce)
#         5    0.000    0.000    0.000    0.000 managers.py:1764(is_consolidated)
#         5    0.000    0.000    0.000    0.000 managers.py:1772(_consolidate_check)
#         5    0.000    0.000    0.000    0.000 managers.py:1782(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 managers.py:1796(concat_horizontal)
#      3094    0.001    0.000    0.001    0.000 managers.py:180(blknos)
#      3094    0.002    0.000    0.002    0.000 managers.py:1837(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:1850(from_blocks)
#         2    0.000    0.000    0.000    0.000 managers.py:1863(from_array)
#      3094    0.001    0.000    0.001    0.000 managers.py:1940(_block)
#      3093    0.001    0.000    0.001    0.000 managers.py:196(blklocs)
#     12368    0.011    0.000    0.014    0.000 managers.py:1993(dtype)
#      6186    0.002    0.000    0.002    0.000 managers.py:2004(internal_values)
#         2    0.000    0.000    0.000    0.000 managers.py:2095(create_block_manager_from_blocks)
#         1    0.000    0.000    0.000    0.000 managers.py:2121(create_block_manager_from_column_arrays)
#         1    0.000    0.000    0.000    0.000 managers.py:2177(_grouping_func)
#         1    0.000    0.000    0.000    0.000 managers.py:2190(_form_blocks)
#         1    0.000    0.000    0.000    0.000 managers.py:2246(_stack_arrays)
#         8    0.000    0.000    0.000    0.000 managers.py:236(set_axis)
#      3098    0.001    0.000    0.001    0.000 managers.py:246(items)
#         1    0.000    0.000    0.000    0.000 managers.py:287(get_dtypes)
#         1    0.000    0.000    0.000    0.000 managers.py:288(<listcomp>)
#         4    0.000    0.000    0.000    0.000 managers.py:291(arrays)
#         4    0.000    0.000    0.000    0.000 managers.py:303(<listcomp>)
#         5    0.000    0.000    0.000    0.000 managers.py:317(apply)
#         5    0.000    0.000    0.000    0.000 managers.py:344(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 managers.py:421(astype)
#         2    0.000    0.000    0.000    0.000 managers.py:557(copy)
#         4    0.000    0.000    0.000    0.000 managers.py:583(copy_func)
#         2    0.000    0.000    0.000    0.000 managers.py:586(<listcomp>)
#         3    0.000    0.000    0.000    0.000 managers.py:623(reindex_indexer)
#         3    0.000    0.000    0.000    0.000 managers.py:687(<listcomp>)
#         2    0.000    0.000    0.000    0.000 managers.py:869(take)
#        16    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         1    0.000    0.000    0.000    0.000 managers.py:935(_verify_integrity)
#         3    0.000    0.000    0.000    0.000 managers.py:937(<genexpr>)
#         8    0.000    0.000    0.000    0.000 managers.py:948(from_blocks)
#         1    0.000    0.000    0.000    0.000 managers.py:958(fast_xs)
#         1    0.000    0.000    0.000    0.000 merge.py:1002(_maybe_add_join_keys)
#         1    0.000    0.000    0.000    0.000 merge.py:1012(<genexpr>)
#         1    0.000    0.000    0.000    0.000 merge.py:1129(_get_join_info)
#         1    0.000    0.000    0.000    0.000 merge.py:1232(_get_merge_keys)
#         1    0.000    0.000    0.001    0.001 merge.py:135(merge)
#         1    0.000    0.000    0.000    0.000 merge.py:1363(_maybe_coerce_merge_keys)
#         1    0.000    0.000    0.000    0.000 merge.py:1554(_validate_left_right_on)
#         3    0.000    0.000    0.000    0.000 merge.py:2680(_any)
#         4    0.000    0.000    0.000    0.000 merge.py:2684(_validate_operand)
#         1    0.000    0.000    0.000    0.000 merge.py:2697(_items_overlap_with_suffix)
#         1    0.000    0.000    0.000    0.000 merge.py:737(__init__)
#         1    0.000    0.000    0.000    0.000 merge.py:815(_maybe_require_matching_dtypes)
#         1    0.000    0.000    0.000    0.000 merge.py:821(_validate_tolerance)
#         1    0.000    0.000    0.001    0.001 merge.py:825(_reindex_and_concat)
#         1    0.000    0.000    0.001    0.001 merge.py:882(get_result)
#         1    0.000    0.000    0.000    0.000 merge.py:958(_maybe_restore_index_levels)
# 9270/9269    0.006    0.000    2.011    0.000 missing.py:101(isna)
# 9270/9269    0.018    0.000    2.005    0.000 missing.py:184(_isna)
#      6180    1.966    0.000    1.974    0.000 missing.py:261(_isna_array)
#      9268    0.066    0.000    2.079    0.000 missing.py:380(notna)
#         3    0.000    0.000    0.000    0.000 missing.py:466(array_equivalent)
#         1    0.000    0.000    0.000    0.000 missing.py:564(_array_equivalent_object)
#         4    0.000    0.000    0.000    0.000 missing.py:673(na_value_for_dtype)
#        10    0.000    0.000    0.000    0.000 multiarray.py:1080(copyto)
#       370    0.000    0.000    0.000    0.000 multiarray.py:153(concatenate)
#       368    0.000    0.000    0.000    0.000 multiarray.py:669(result_type)
#       368    0.000    0.000    0.000    0.000 multiarray.py:741(dot)
#      3089    0.103    0.000    2.283    0.001 nanops.py:1586(nancorr)
#       368    0.000    0.000    0.000    0.000 nanops.py:1618(get_corr_func)
#       368    0.001    0.000    0.074    0.000 nanops.py:1637(func)
#       736    0.001    0.000    0.001    0.000 nanops.py:1678(_ensure_numeric)
#         2    0.000    0.000    0.000    0.000 nanops.py:543(nanall)
#     12356    0.006    0.000    0.010    0.000 nanops.py:72(check)
#      3089    0.017    0.000    2.324    0.001 nanops.py:76(_f)
#     15445    0.009    0.000    0.019    0.000 nanops.py:79(<genexpr>)
#         2    0.000    0.000    0.000    0.000 numeric.py:2374(_array_equal_dispatcher)
#         2    0.000    0.000    0.000    0.000 numeric.py:2378(array_equal)
#        10    0.000    0.000    0.000    0.000 numeric.py:274(full)
#     12356    0.008    0.000    0.012    0.000 numerictypes.py:283(issubclass_)
#      6178    0.011    0.000    0.024    0.000 numerictypes.py:357(issubdtype)
#      3090    0.006    0.000    0.014    0.000 series.py:1471(_set_as_cached)
#         4    0.000    0.000    0.000    0.000 series.py:1480(_clear_item_cache)
#      3089    0.019    0.000    2.556    0.001 series.py:2899(corr)
#       3/2    0.000    0.000    0.001    0.001 series.py:389(__init__)
#      6178    0.004    0.000    0.006    0.000 series.py:4926(_reindex_indexer)
#         1    0.000    0.000    0.001    0.001 series.py:607(_init_dict)
#         1    0.000    0.000    0.000    0.000 series.py:6418(_reduce)
#         1    0.000    0.000    0.000    0.000 series.py:6480(all)
#         1    0.000    0.000    0.000    0.000 series.py:664(_constructor_from_mgr)
#     12368    0.007    0.000    0.020    0.000 series.py:707(dtype)
#         6    0.000    0.000    0.000    0.000 series.py:734(name)
#         3    0.000    0.000    0.000    0.000 series.py:784(name)
#      6186    0.004    0.000    0.006    0.000 series.py:831(_values)
#         2    0.000    0.000    0.000    0.000 series.py:865(_references)
#      3092    0.002    0.000    0.013    0.000 series.py:914(__len__)
#         1    0.000    0.000    0.000    0.000 series.py:978(__array__)
#         1    0.000    0.000    0.000    0.000 sorting.py:369(nargsort)
#       368    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#       368    0.005    0.000    0.007    0.000 stride_tricks.py:340(_broadcast_to)
#       736    0.000    0.000    0.000    0.000 stride_tricks.py:345(<genexpr>)
#       368    0.000    0.000    0.000    0.000 stride_tricks.py:363(_broadcast_to_dispatcher)
#       368    0.000    0.000    0.008    0.000 stride_tricks.py:367(broadcast_to)
#         2    0.000    0.000    0.000    0.000 string_.py:140(construct_from_string)
#         4    0.000    0.000    0.000    0.000 take.py:120(_take_nd_ndarray)
#         4    0.000    0.000    0.000    0.000 take.py:325(_get_take_nd_function)
#         4    0.000    0.000    0.000    0.000 take.py:564(_take_preprocess_indexer_and_fill_value)
#         4    0.000    0.000    0.000    0.000 take.py:59(take_nd)
#       368    0.000    0.000    0.000    0.000 twodim_base.py:230(_diag_dispatcher)
#       368    0.001    0.000    0.003    0.000 twodim_base.py:234(diag)
#       368    0.000    0.000    0.000    0.000 type_check.py:205(_is_type_dispatcher)
#       368    0.001    0.000    0.001    0.000 type_check.py:302(iscomplexobj)
#      3116    0.001    0.000    0.001    0.000 typing.py:1375(cast)
#         2    0.000    0.000    0.000    0.000 utils.py:239(maybe_convert_indices)
#         3    0.000    0.000    0.000    0.000 utils.py:38(is_valid_positional_slice)
#         1    0.000    0.000    0.000    0.000 utils.py:419(check_array_indexer)
#         1    0.000    0.000    0.000    0.000 utils.py:62(is_list_like_indexer)
#         2    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         2    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         3    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#         3    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#         3    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#      3121    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x00007FFF6C8BDC60}
#        44    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#         8    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#       295    0.002    0.000    0.002    0.000 {built-in method _warnings.warn}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#      3461    0.005    0.000    0.024    0.000 {built-in method builtins.any}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    2.760    2.760 {built-in method builtins.exec}
#     25585    0.006    0.000    0.006    0.000 {built-in method builtins.getattr}
#     12388    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 85974/79779    0.026    0.000    0.050    0.000 {built-in method builtins.isinstance}
#     25852    0.007    0.000    0.007    0.000 {built-in method builtins.issubclass}
#       370    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 25712/16357    0.010    0.000    0.018    0.000 {built-in method builtins.len}
#       736    0.001    0.000    0.002    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#      1107    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#      1840    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
# 6945/6944    0.004    0.000    0.004    0.000 {built-in method numpy.asarray}
#       368    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x00000198831A9D30}
#       368    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#         3    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#      3093    0.005    0.000    0.034    0.000 {method 'all' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       368    0.000    0.000    0.003    0.000 {method 'clip' of 'numpy.ndarray' objects}
#       368    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       381    0.001    0.000    0.001    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       368    0.001    0.000    0.001    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#       368    0.001    0.000    0.018    0.000 {method 'mean' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      3467    0.028    0.000    0.028    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       368    0.000    0.000    0.000    0.000 {method 'reset' of 'ContextVar' objects}
#         2    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#       368    0.000    0.000    0.000    0.000 {method 'set' of 'ContextVar' objects}
#         8    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       368    0.000    0.000    0.000    0.000 {method 'squeeze' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#      3090    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}

# %% [markdown]
# ### Precision y Recall

# %% [markdown]
# Estas métricas se utilizan para evaluar la calidad de las recomendaciones en términos de cuántas de las recomendaciones son relevantes y cuántos de los elementos relevantes han sido recomendados.

# %%
mean_ratings = common_clothes.groupby('item_id')['rating'].mean()
mean_ratings_sorted = mean_ratings.sort_values(ascending=False)
print(mean_ratings_sorted)
# Out:
# item_id
# 1384226    10.000000
# 1451390    10.000000
# 1011971    10.000000
# 1817701    10.000000
# 1888892    10.000000
#              ...
# 2186524     6.941176
# 753871      6.923077
# 679340      6.750000
# 796216      6.727273
# 2626811     6.666667
# Name: rating, Length: 3089, dtype: float64

# %%
# Filtrar por valor igual a 10
mean_ratings_equal_to_10 = mean_ratings[mean_ratings >= 9]
# Contar los elementos
relevant_items = mean_ratings_equal_to_10.count()
print("Número de elementos con promedio de calificación igual a 9:", relevant_items)
# Out:
# Número de elementos con promedio de calificación igual a 9: 1933

# %%
def clothes_recommend(clothe, head):
    
    if clothe in user_clothe_rating.columns:
        clothes_rating = user_clothe_rating[clothe] # Prenda base para correlación
        corr_clothes = user_clothe_rating.corrwith(clothes_rating) # Función de correlación
        result_df = pd.DataFrame(corr_clothes, columns=['Correlation'])
        result_df.dropna(inplace=True)
        result_df = result_df.join(ratings_mean_count['rating_counts'])
        result_df = result_df.sort_values('Correlation', ascending=False)
        mean_ratings_equal_to_10 = result_df[result_df['Correlation'] >= 0.8]
        return(mean_ratings_equal_to_10)
    else:
        return None

# %%
recommended_items = clothes_recommend(127495,11)
recommended_items.reset_index(inplace=True)
recommended_items.rename(columns={'index': 'item_id'}, inplace=True)

# %%
def precision_at_k(recommended_items, relevant_items, k):
    recommended_k = recommended_items[:k]
    relevant_set = set(relevant_items)
    recommended_set = set(recommended_k)
    return len(recommended_set & relevant_set) / len(recommended_set)

def recall_at_k(recommended_items, relevant_items, k):
    recommended_k = recommended_items[:k]
    relevant_set = set(relevant_items)
    recommended_set = set(recommended_k)
    return len(recommended_set & relevant_set) / len(relevant_set)

# %%
precision = precision_at_k(recommended_items['item_id'], mean_ratings_equal_to_10.index, k=2)
recall = recall_at_k(recommended_items['item_id'], mean_ratings_equal_to_10.index, k=2)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# Precision: 1.0
# Recall: 0.0010346611484738748

# %% [markdown]
# ### Coverage

# %% [markdown]
# Esta métrica mide la proporción de elementos que el sistema de recomendación puede recomendar. Es una métrica útil para evaluar la diversidad del sistema.

# %%
def coverage(recommended_items, all_items):
    recommended_set = set(recommended_items)
    all_items_set = set(all_items)
    return len(recommended_set & all_items_set) / len(all_items_set)

# %%
coverage = coverage(recommended_items['item_id'], common_clothes['item_id'])
print(f'coverage: {coverage}')
# Out:
# coverage: 0.00712204596956944

# %% [markdown]
# ### Mean Average Precision (MAP)

# %% [markdown]
# Esta métrica evalúa la precisión promedio para las listas de recomendaciones, ponderada por la posición de los elementos relevantes en la lista.

# %%
def average_precision(recommended_items, relevant_items):
    relevant_set = set(relevant_items)
    if not relevant_set:
        return 0.0
    score = 0.0
    num_hits = 0.0
    for i, item in enumerate(recommended_items):
        if item in relevant_set:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    return score / min(len(relevant_set), len(recommended_items))

# %%
average_precision = average_precision(recommended_items['item_id'], common_clothes['item_id'])

print(f'average_precision: {average_precision}')
# Out:
# average_precision: 1.0
